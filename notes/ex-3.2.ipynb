# %% [markdown]
# # GRAPHICS AND VISUALIZATION

# %% [markdown]
# ## Graphs

# %%
from  pylab import*

# %%
from numpy import*

# %% [markdown]
# ### Exercise 3.2: Curve plotting

# %% [markdown]
# ##### a) Make a plot of the so-called $\textit{deltoid}$ curve, which is defined parametrically by the equations:
# ##### $x = 2\cos(\theta) + cos(2*\theta)$, $y = 2sin(\theta) - sin(2\theta)$
# ##### where $0<\theta<2\pi$. Take a set of values of $\theta$ between zero and $2\pi$ anda calculate $x$ and $y$ for each from the equations above, then plot $y$ as a function of $x$.

# %%
theta = linspace(0, 2*pi, 100)

# %%
x = 2*cos(theta) + cos(2*theta)

# %%
y = 2*sin(theta) - sin(2*theta)

# %%
plot(x, y, label = r'$x = 2cos(\theta) + cos(2\theta), y = 2sin(\theta) - sin(2\theta)$')
legend()
title("Deltoide")
ylabel(r"$y(\theta)$")
xlabel(r"$x(\theta)$")
show()

# %% [markdown]
# ##### b) Taking this approach a step further, one can make a polar plot $r = f(\theta)$ for some function $f$ calculando $r$  for a range of values of $\theta$ an then converting  $r$ and $\theta$ to Cartesian coordinates using the standard equations  $x=rcos(\theta)$, $y = rsin(\theta)$. Use this mehod to make a plot of the Galilean spiral $r=\theta^{2}$ for $0<\theta<10\pi$.

# %%
theta2 = linspace(0, 10*pi, 500)

# %%
r = theta2**2

# %%
x2 = r*cos(theta2)

# %%
y2 = r*sin(theta2)

# %%
plot(x2,y2)
title('Espiral de Galileo')
xlabel(r'$\theta$')
ylabel(r'$r = \theta^{2}$')
grid()
show()

# %% [markdown]
# ##### c) Using the same method, make a polar plot of "Fey's function"
# $r = e^{cos(\theta)} - 2cos(4\theta) + sin^{5}(\frac{\theta}{12})$
# ##### in the range $0< \theta < 24\pi$

# %%
theta3 = linspace(0, 24*pi, 2000)

# %%
r3 = pow(e,cos(theta3)) - 2*cos(4*theta3) + (sin(theta3/12))**5

# %%
x3 = r3*cos(theta3)

# %%
y3 = r3*sin(theta3)

# %%
plot(x3,y3, 'g--')
title("Fey's function")
xlabel(r'$\theta$')
ylabel(r'$r = e^{cos(\theta)} - 2cos(4\theta) + sin^{5}(\frac{\theta}{12})$')
show()
